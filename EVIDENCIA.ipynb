# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-bdc129e3-782a-4b63-b029-5552bdaa110a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bdc129e3-782a-4b63-b029-5552bdaa110a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

import io

# %%
df
# Out:
#       IdClase  Sobreviviente                                           Nombre  \
# 0           1              1                    Allen, Miss. Elisabeth Walton
# 1           1              1                   Allison, Master. Hudson Trevor
# 2           1              0                     Allison, Miss. Helen Loraine
# 3           1              0             Allison, Mr. Hudson Joshua Creighton
# 4           1              0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...       ...            ...                                              ...
# 1304        3              0                             Zabour, Miss. Hileni
# 1305        3              0                            Zabour, Miss. Thamine
# 1306        3              0                        Zakarian, Mr. Mapriededer
# 1307        3              0                              Zakarian, Mr. Ortin
# 1308        3              0                               Zimmerman, Mr. Leo
#
#       Genero     Edad  \
# ...

# %% [markdown]
# # ***Muestra la forma de un conjunto de datos usando shape***

# %%
df.shape
# Out:
# (1309, 13)

# %%
print (len(df))
# Out:
# 1309

# %%
print(df.shape[1])
# Out:
# 13

# %%
df.head(5)
# Out:
#    IdClase  Sobreviviente                                           Nombre  \
# 0        1              1                    Allen, Miss. Elisabeth Walton
# 1        1              1                   Allison, Master. Hudson Trevor
# 2        1              0                     Allison, Miss. Helen Loraine
# 3        1              0             Allison, Mr. Hudson Joshua Creighton
# 4        1              0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#    Genero     Edad  \
# 0  female  29.0000
# 1    male   0.9167
# 2  female   2.0000
# 3    male  30.0000
# 4  female  25.0000
#
#    Número de hermanos, hermanas, hermanastros o hermanastras en el barco.  \
# 0                                                  0
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
# ...

# %% [markdown]
# # ***Para ver las primeras 5 filas del dataframe***

# %%
df.head(5)
# Out:
#    IdClase  Sobreviviente                                           Nombre  \
# 0        1              1                    Allen, Miss. Elisabeth Walton
# 1        1              1                   Allison, Master. Hudson Trevor
# 2        1              0                     Allison, Miss. Helen Loraine
# 3        1              0             Allison, Mr. Hudson Joshua Creighton
# 4        1              0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#    Genero     Edad  \
# 0  female  29.0000
# 1    male   0.9167
# 2  female   2.0000
# 3    male  30.0000
# 4  female  25.0000
#
#    Número de hermanos, hermanas, hermanastros o hermanastras en el barco.  \
# 0                                                  0
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(_df_27['Camarote'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(_df_27, x='index', y='Camarote', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(_df_26['Ticket'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(_df_26, x='index', y='Ticket', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(_df_25['Genero'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(_df_25, x='index', y='Genero', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(_df_24['Nombre'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(_df_24, x='index', y='Nombre', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Bote'].value_counts()
    for x_label, grp in _df_23.groupby('Camarote')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Camarote')
_ = plt.ylabel('Bote')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Camarote'].value_counts()
    for x_label, grp in _df_22.groupby('Ticket')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Ticket')
_ = plt.ylabel('Camarote')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Ticket'].value_counts()
    for x_label, grp in _df_21.groupby('Genero')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Genero')
_ = plt.ylabel('Ticket')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Genero'].value_counts()
    for x_label, grp in _df_20.groupby('Nombre')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Nombre')
_ = plt.ylabel('Genero')

# %%
from matplotlib import pyplot as plt
_df_19['Número de hermanos, hermanas, hermanastros o hermanastras en el barco.'].plot(kind='line', figsize=(8, 4), title='Número de hermanos, hermanas, hermanastros o hermanastras en el barco.')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_18['Edad'].plot(kind='line', figsize=(8, 4), title='Edad')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_17['Sobreviviente'].plot(kind='line', figsize=(8, 4), title='Sobreviviente')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_16['index'].plot(kind='line', figsize=(8, 4), title='index')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['index']
  ys = series['Sobreviviente']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_15.sort_values('index', ascending=True)
for i, (series_name, series) in enumerate(df_sorted.groupby('Camarote')):
  _plot_series(series, series_name, i)
  fig.legend(title='Camarote', bbox_to_anchor=(1, 1), loc='upper left')
sns.despine(fig=fig, ax=ax)
plt.xlabel('index')
_ = plt.ylabel('Sobreviviente')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['index']
  ys = series['Sobreviviente']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_14.sort_values('index', ascending=True)
for i, (series_name, series) in enumerate(df_sorted.groupby('Ticket')):
  _plot_series(series, series_name, i)
  fig.legend(title='Ticket', bbox_to_anchor=(1, 1), loc='upper left')
sns.despine(fig=fig, ax=ax)
plt.xlabel('index')
_ = plt.ylabel('Sobreviviente')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['index']
  ys = series['Sobreviviente']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_13.sort_values('index', ascending=True)
for i, (series_name, series) in enumerate(df_sorted.groupby('Genero')):
  _plot_series(series, series_name, i)
  fig.legend(title='Genero', bbox_to_anchor=(1, 1), loc='upper left')
sns.despine(fig=fig, ax=ax)
plt.xlabel('index')
_ = plt.ylabel('Sobreviviente')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['index']
  ys = series['Sobreviviente']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_12.sort_values('index', ascending=True)
for i, (series_name, series) in enumerate(df_sorted.groupby('Nombre')):
  _plot_series(series, series_name, i)
  fig.legend(title='Nombre', bbox_to_anchor=(1, 1), loc='upper left')
sns.despine(fig=fig, ax=ax)
plt.xlabel('index')
_ = plt.ylabel('Sobreviviente')

# %%
from matplotlib import pyplot as plt
_df_11.plot(kind='scatter', x='Número de hermanos, hermanas, hermanastros o hermanastras en el barco.', y='Número de padres e hijos en el barco.', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_10.plot(kind='scatter', x='Edad', y='Número de hermanos, hermanas, hermanastros o hermanastras en el barco.', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_9.plot(kind='scatter', x='Sobreviviente', y='Edad', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_8.plot(kind='scatter', x='index', y='Sobreviviente', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_7.groupby('Camarote').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_6.groupby('Ticket').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_9.plot(kind='scatter', x='Sobreviviente', y='Edad', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_8.plot(kind='scatter', x='index', y='Sobreviviente', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_7.groupby('Camarote').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_6.groupby('Ticket').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_5.groupby('Genero').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_4.groupby('Nombre').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_3['Número de hermanos, hermanas, hermanastros o hermanastras en el barco.'].plot(kind='hist', bins=20, title='Número de hermanos, hermanas, hermanastros o hermanastras en el barco.')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_2['Edad'].plot(kind='hist', bins=20, title='Edad')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_1['Sobreviviente'].plot(kind='hist', bins=20, title='Sobreviviente')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_0['index'].plot(kind='hist', bins=20, title='index')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# *El 0 tambien se cuenta por lo que si queremos que llegue hasta el 5 tendremos que poner 6 en el parentesis *

# %% [markdown]
# # ***Especifiar la columna llamada "NAME"***

# %%
df['Nombre']
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: Nombre, Length: 1309, dtype: object
